# %%
record = { 1001 : {"name": "lcz5mg" , "expirydate": "2/2/2022", "mfd" : "24/12/2019" , "sellername": "krishna" , "quantity": 100 , "prize": 265 },
           1002 : {"name": "lcz10mg", "expirydate": "5/12/2022","mfd" : "24/12/2019" ,  "sellername": "tulsian" , "quantity":  100 , "prize": 265  },
           1003 : {"name": "paracetomal500mg"   , "expirydate": "24/2/2025", "mfd" : "24/12/2019" , "sellername": "novelty" , "quantity":100, "prize": 265  },
           1004 : {"name": "paracetomal650mg" , "expirydate": "24/12/2024", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity": 100, "prize": 265  },
           1005 : {"name": "montair lc" , "expirydate": "24/2/2021", "mfd" : "24/12/2019" , "sellername": "satya" , "quantity":100 , "prize": 265},
           1006 : {"name": "amtas 5mg", "expirydate": "24/1/2025","mfd" : "24/12/2019" , "sellername": "bilasrai" , "quantity":  100, "prize": 265},
           1007 : {"name": "emlovas5mg"   , "expiryate": "2/12/2022", "mfd" : "24/12/2019" , "sellername": "ashok" , "quantity":100, "prize": 265},
           1008 : {"name": "citrizne10mg" , "expirydate": "2/2/2026", "mfd" : "24/12/2019" , "sellername": "krishna" , "quantity": 100, "prize": 265},
           1009 : {"name": "azicip500mg", "expirydate": "24/2/2025","mfd" : "24/12/2019" , "sellername": "tulsian" , "quantity":  100 , "prize": 265 },
           1010 : {"name": "azicip250mg"   , "expiryate": "2/2/2030", "mfd" : "24/12/2019" , "sellername": "novelty" , "quantity": 100, "prize": 265},
           1011 : {"name": "azee500mg" , "expirydate": "6/12/2024", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity":  100, "prize": 265},
           1012 : {"name": "azee250mg", "expirydate": "24/12/2022","mfd" : "24/12/2019" , "sellername": "satya" , "quantity":   100, "prize": 265},
           1013 : {"name": "montas l"   , "expiryate": "24/8/2023", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity": 100, "prize": 26},
           1014 : {"name": "aldespic p" , "expirydate": "2/5/2026", "mfd" : "24/12/2019" , "sellername": "satya" , "quantity":  100, "prize": 26526},
           1015 : {"name": "aldespic sp", "expirydate": "2/4/2028","mfd" : "24/12/2019" , "sellername": "krishna" , "quantity":100  , "prize": 245 },
           1016 : {"name": "saredic p"   , "expiryate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "novelty" , "quantity":100 , "prize": 265 },
           1017 : {"name": "zeradol p" , "expirydate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "tulsian" , "quantity":  100, "prize": 265 },
           1018 : {"name": "zeradol sp", "expirydate": "24/12/2022","mfd" : "24/12/2019" , "sellername": "rama" , "quantity":100  , "prize": 265   },
           1019 : {"name": "zeradol mr"   , "expiryate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "novelty" , "quantity":100 , "prize": 265 },
           1020 : {"name": "zeradol" , "expirydate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity":  100, "prize": 265 },
           1021 : {"name": "zeradol cr", "expirydate": "24/12/2022","mfd" : "24/12/2019" , "sellername": "krishna" , "quantity": 100   , "prize": 265 },
           1022 : {"name": "febrex plus"   , "expiryate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "krishna" , "quantity":100 , "prize": 265 },
           1023 : {"name": "combiflam" , "expirydate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "krishna" , "quantity":  100, "prize": 265 },
           1024 : {"name": "intrasic", "expirydate": "24/12/2022","mfd" : "24/12/2019" , "sellername": "krishna" , "quantity":    100, "prize": 265 },
           1025 : {"name": "intrasic mr"   , "expiryate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity": 100, "prize": 265 },
           1026 : {"name": "ciplar a 40mg" , "expirydate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity":  100, "prize": 265 },
           1027 : {"name": "ciplox 500mg", "expirydate": "24/12/2022","mfd" : "24/12/2019" , "sellername": "rama" , "quantity":    100, "prize": 265 },
           1028 : {"name": "ampilox 500mg"   , "expiryate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity": 100, "prize": 265 },
           1029 : {"name": "amoxyclave 625mg" , "expirydate": "24/12/2022", "mfd" : "24/12/2019" , "sellername": "rama" , "quantity":  100, "prize": 265 },
           1030 : {"name": "amoxyclave 375mg", "expirydate": "24/12/2022","mfd" : "24/12/2019" , "sellername": "rama" , "quantity":  100 , "prize": 265  },}

# %%
import json

# %%
js = json.dumps(record)

# %%
fd = open("record.txt",'w')

fd.write(js)

fd.close()

# %%
fd = open("record.json",'w')

fd.write(js)

fd.close()

# %%
record
# Out:
# {1001: {'name': 'lcz5mg',
#   'expirydate': '2/2/2022',
#   'mfd': '24/12/2019',
#   'sellername': 'krishna',
#   'quantity': 100,
#   'prize': 265},
#  1002: {'name': 'lcz10mg',
#   'expirydate': '5/12/2022',
#   'mfd': '24/12/2019',
#   'sellername': 'tulsian',
#   'quantity': 100,
#   'prize': 265},
#  1003: {'name': 'paracetomal500mg',
#   'expirydate': '24/2/2025',
#   'mfd': '24/12/2019',
#   'sellername': 'novelty',
#   'quantity': 100,
#   'prize': 265},
#  1004: {'name': 'paracetomal650mg',
#   'expirydate': '24/12/2024',
#   'mfd': '24/12/2019',
#   'sellername': 'rama',
#   'quantity': 100,
#   'prize': 265},
#  1005: {'name': 'montair lc',
#   'expirydate': '24/2/2021',
#   'mfd': '24/12/2019',
#   'sellername': 'satya',
#   'quantity': 100,
#   'prize': 265},
#  1006: {'name': 'amtas 5mg',
#   'expirydate': '24/1/2025',
#   'mfd': '24/12/2019',
#   'sellername': 'bilasrai',
#   'quantity': 100,
#   'prize': 265},
#  1007: {'name': 'emlovas5mg',
# ...

# %%
record[1003]['quantity']
# Out:
# 100
